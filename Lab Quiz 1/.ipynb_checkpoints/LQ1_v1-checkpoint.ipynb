# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ### Task#1: Load/read images cat.jpeg and cameraman.tif [1 mark]

# %%
# Load/read images cat.jpeg and cameraman.tif [1 mark]
import cv2
# path issue here, code wont run cv2.imshow()
img1 = cv2.imread('cat.jpeg')
img2 = cv2.imread('cameraman.tif')
cv2.imshow("cat", img1)
cv2.imshow("cameraman", img2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[20], line 5
#       3 img1 = cv2.imread('Lab Quiz 1/cat.jpeg')
#       4 img2 = cv2.imread('Lab Quiz 1/cameraman.tif')
# ----> 5 cv2.imshow("cat", img1)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %% [markdown]
# ### Task#2: Add the two images, and display the result [2 marks]

# %%
# Add the two images, and display the result [2 marks]
img1 = cv2.imread('Images/cat.jpeg')
img2 = cv2.imread('Images/cameraman.tif')
resize = [400, 400]
# same error here
img1 = cv2.resize(img1, resize)
img2 = cv2.resize(img2, resize)
img3 = cv2.add(img1, img2)
cv2.imshow("new", img3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[23], line 5
#       3 img2 = cv2.imread('Images/cameraman.tif')
#       4 resize = [400, 400]
# ----> 5 img1 = cv2.resize(img1, resize)
#       6 img2 = cv2.resize(img2, resize)
#       7 img3 = cv2.add(img1, img2)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %% [markdown]
# kernel1= [[-1, -2, -1],
#           [0, 0, 0],
#            [1, 2, 1]]
#
# kernel2= [[-1, 0, 1],
#           [-2, 0, 2],
#           [-1, 0, 1]]
#
#
#
# ### Task#3: Using kernel1 and kernel2 apply convolution to cameraman.tif, and display the output image [2 marks]

# %%
#Using kernel1 and kernel2 apply convolution to cameraman.tif, and display the output image [2 marks]
kernel1 = np.array([[-1, -2, -1],
                   [0, 0, 0],
                   [1, 2, 1]])

kernel2 = np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])
